# %%
1111

# %%
np
# Out:
# Running cells with 'Python 3.7.13 64-bit ('3.7.13')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/user/.pyenv/versions/3.7.13/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
np
# Out:
# Running cells with 'Python 3.7.13 64-bit ('3.7.13')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/user/.pyenv/versions/3.7.13/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
11
# Out:
# Running cells with 'Python 3.7.13 64-bit ('3.7.13')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/user/.pyenv/versions/3.7.13/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
np
# Out:
# Running cells with 'Python 3.7.13 64-bit ('3.7.13')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/user/.pyenv/versions/3.7.13/bin/python -m pip install ipykernel -U --force-reinstall'
